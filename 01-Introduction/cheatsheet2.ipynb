# %% [markdown]
# The Pandas us built on Numpy and provide easy to use data structure and data analysis tool for the python programming

# %%
import pandas as pd

# %%
# a series
s = pd.Series([3,-5,7,4], index=['a','b','c','d'])
s
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %%
# dataframe
